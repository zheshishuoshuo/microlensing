# %%
import numpy as np
import matplotlib.pyplot as plt

from microlensing.Util import util

# %%
is_ipm = True
is_double = False
prefix = ''
if is_ipm:
    prefix = f'{prefix}ipm_'
else:
    prefix = f'{prefix}irs_'

# %%
params = util.read_params(f'{prefix}parameter_info.txt')
params
# Out:
# {'kappa_tot': 0.400000006,
#  'shear': 0.400000006,
#  'mu_ave': 5,
#  'smooth_fraction': 0.5,
#  'kappa_star': 0.200000003,
#  'kappa_star_actual': 0.200000003,
#  'theta_star': 1,
#  'random_seed': 1831419855,
#  'mass_function': 'equal',
#  'm_lower': 1,
#  'm_upper': 1,
#  'mean_mass': 1,
#  'mean_mass2': 1,
#  'mean_mass2_ln_mass': 0,
#  'm_lower_actual': 1,
#  'm_upper_actual': 1,
#  'mean_mass_actual': 1,
#  'mean_mass2_actual': 1,
#  'mean_mass2_ln_mass_actual': 0,
#  'light_loss': 0.00100000005,
#  'num_stars': 3663,
#  'corner_x1': 53.640976,
#  'corner_x2': 268.163757,
#  'taylor_smooth': 35,
#  'safety_scale': 1.37,
#  'center_y1': 0,
#  'center_y2': 0,
#  'half_length_y1': 25,
#  'half_length_y2': 25,
#  'num_pixels_y1': 5000,
#  'num_pixels_y2': 5000,
#  'center_x1': 0,
#  'center_x2': 0,
#  'half_length_x1': 39.1499977,
#  'half_length_x2': 195.720001,
#  'num_rays_y': 1,
#  'num_rays_x': 10000,
#  'ray_half_sep_1': 0.00499999989,
#  'ray_half_sep_2': 0.00499999989,
#  'alpha_error': 0.000500000024,
#  'expansion_order': 10,
#  'root_half_length': 294.980133,
#  'num_ray_threads_1': 7830,
#  'num_ray_threads_2': 39144,
#  'tree_levels': 7,
#  't_shoot_cells': 11.393}

# %%
stars, _, _, theta_star = util.read_stars(f'{prefix}stars.bin', np.float32)
print(stars.shape)
# Out:
# (3663, 3)

# %%
fig, ax = plt.subplots()
ax.scatter(stars[:, 0] / theta_star, stars[:, 1] / theta_star, s=stars[:,2])

ax.set_xlabel('$x_1 / \\theta_★$')
ax.set_ylabel('$x_2 / \\theta_★$')

ax.set_aspect(1)

plt.show()

# %%
dat = util.read_array(f'{prefix}magnifications.bin', np.float32)
# magnification
if is_ipm:
    mu = dat
else:
    mu = dat / params['num_rays_y']
print(np.min(mu))
print(np.max(mu))
print(np.mean(mu))
# astronomical magnitudes
mags = -2.5*np.log10(mu / np.abs(params['mu_ave']))
print(np.max(mags))
print(np.min(mags))
# Out:
# 1.8600428
# 175.45502
# 4.8452454
# 1.0736177
# -3.8629894

# %%
fig, ax = plt.subplots()
ax.imshow(mags[:,:], extent = [params['center_y1'] - params['half_length_y1'], 
                               params['center_y1'] + params['half_length_y1'], 
                               params['center_y2'] - params['half_length_y2'], 
                               params['center_y2'] + params['half_length_y2']],
          cmap = 'viridis_r')

ax.set_xlabel('$y_1 / \\theta_★$')
ax.set_ylabel('$y_2 / \\theta_★$')

ax.set_aspect(params['half_length_y1'] / params['half_length_y2'])

plt.show()

# %%
fig, ax = plt.subplots()

y1, step = np.linspace(params['center_y1'] - params['half_length_y1'],
                       params['center_y1'] + params['half_length_y1'],
                       params['num_pixels_y1'],
                       endpoint = False, retstep=True)
y1 += step/2

y2, step = np.linspace(params['center_y2'] - params['half_length_y2'],
                       params['center_y2'] + params['half_length_y2'],
                       params['num_pixels_y2'],
                       endpoint = False, retstep=True)
y2 += step/2

where = slice(0,1000)

ax.plot(y1[where], mags[100, where], label = '$y_1$')
ax.plot(y2[where], mags[where, 100], label = '$y_2$')

ax.legend()

ax.set_xlabel('$y_i / \\theta_★$')
ax.set_ylabel('microlensing $\\Delta m$ (magnitudes)')

ax.invert_yaxis()

plt.show()

# %%
# magnification
if is_ipm:
    dat, num_pixels = util.read_hist(f'{prefix}mags_numpixels.txt').T
    mu = dat / 1000
else:
    dat, num_pixels = util.read_hist(f'{prefix}numrays_numpixels.txt').T
    mu = dat / params['num_rays_y']
# astronomical magnitudes
mags = -2.5*np.log10(mu / np.abs(params['mu_ave']))

fig, ax = plt.subplots()
ax.hist(mags, weights=num_pixels, density=True, bins = 1000)

ax.set_xlabel("microlensing $\\Delta m$ (magnitudes)")
ax.set_ylabel("$p(\\Delta m)$")

ax.invert_xaxis()

plt.show()
